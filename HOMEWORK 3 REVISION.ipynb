# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('LA_AQS_2023.csv')

# %%
print(df.head())
# Out:
#    State Code  County Code  Site Number  Parameter Code  POC  Latitude  \
# 0           6           37         1103           68103    1  34.06659
# 1           6           37         1103           42602    3  34.06659
# 2           6           37         1103           62201    1  34.06659
# 3           6           37         1103           62101    1  34.06659
# 4           6           37         1103           42603    1  34.06659
#
#    Longitude  Datum            Parameter Name Duration Description  ... AQI  \
# 0 -118.22688  WGS84   Ambient Min Temperature              24 HOUR  ...   .
# 1 -118.22688  WGS84    Nitrogen dioxide (NO2)               1 HOUR  ...  16
# 2 -118.22688  WGS84         Relative Humidity               1 HOUR  ...   .
# 3 -118.22688  WGS84       Outdoor Temperature               1 HOUR  ...   .
# 4 -118.22688  WGS84  Oxides of nitrogen (NOx)               1 HOUR  ...   .
#
#   Daily Criteria Indicator  Tribe Name  State Name  County Name    City Name  \
# ...

# %%
df['Parameter Name']
# Out:
# 0           Ambient Min Temperature
# 1            Nitrogen dioxide (NO2)
# 2                 Relative Humidity
# 3               Outdoor Temperature
# 4          Oxides of nitrogen (NOx)
#                     ...
# 22155               Solar radiation
# 22156    Wind Direction - Resultant
# 22157        Wind Speed - Resultant
# 22158             Relative Humidity
# 22159           Outdoor Temperature
# Name: Parameter Name, Length: 22160, dtype: str

# %%
df_NO2 = df[(df['Parameter Name']=='Nitrogen dioxide (NO2)') & (df['Duration Description']=='1 HOUR')]
df_NO2.head()
# Out:
#     State Code  County Code  Site Number  Parameter Code  POC  Latitude  \
# 1            6           37         1103           42602    3  34.06659
# 19           6           37         1103           42602    1  34.06659
# 29           6           37         1103           42602    1  34.06659
# 41           6           37         1103           42602    3  34.06659
# 44           6           37         1103           42602    3  34.06659
#
#     Longitude  Datum          Parameter Name Duration Description  ... AQI  \
# 1  -118.22688  WGS84  Nitrogen dioxide (NO2)               1 HOUR  ...  16
# 19 -118.22688  WGS84  Nitrogen dioxide (NO2)               1 HOUR  ...  17
# 29 -118.22688  WGS84  Nitrogen dioxide (NO2)               1 HOUR  ...  17
# 41 -118.22688  WGS84  Nitrogen dioxide (NO2)               1 HOUR  ...  16
# 44 -118.22688  WGS84  Nitrogen dioxide (NO2)               1 HOUR  ...  20
#
#    Daily Criteria Indicator  Tribe Name  State Name  County Name    City Name  \
# ...

# %%
df_NO2.columns
# Out:
# Index(['State Code', 'County Code', 'Site Number', 'Parameter Code', 'POC',
#        'Latitude', 'Longitude', 'Datum', 'Parameter Name',
#        'Duration Description', 'Pollutant Standard', 'Date (Local)', 'Year',
#        'Day In Year (Local)', 'Units of Measure', 'Exceptional Data Type',
#        'Nonreg Observation Count', 'Observation Count', 'Observation Percent',
#        'Nonreg Arithmetic Mean', 'Arithmetic Mean',
#        'Nonreg First Maximum Value', 'First Maximum Value',
#        'First Maximum Hour', 'AQI', 'Daily Criteria Indicator', 'Tribe Name',
#        'State Name', 'County Name', 'City Name', 'Local Site Name', 'Address',
#        'MSA or CBSA Name', 'Data Source'],
#       dtype='str')

# %%
ax1 = df_NO2.plot.scatter(x='Date (Local)',y='Arithmetic Mean')

# %%
df_NO2["Date (Local)"] = pd.to_datetime(df_NO2["Date (Local)"])

# %%
date = df_NO2["Date (Local)"]
value = df_NO2["Arithmetic Mean"]

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(date, value)

# %%
import seaborn as sns

# %%
df['Parameter Name'].unique()
# Out:
# <ArrowStringArray>
# [   'Ambient Min Temperature',     'Nitrogen dioxide (NO2)',
#           'Relative Humidity',        'Outdoor Temperature',
#    'Oxides of nitrogen (NOx)',    'Wind Direction - Scalar',
#    'Sample Min Baro Pressure', 'Wind Direction - Resultant',
#    'Sample Max Baro Pressure',        'Elapsed Sample Time',
#  ...
#              'Iron (TSP) STP',        'Strontium (TSP) STP',
#                'Acetaldehyde',               'Formaldehyde',
#         'Methyl ethyl ketone',       'Molybdenum (TSP) STP',
#         'Beryllium (TSP) STP',            'Propionaldehyde',
#               'Butyraldehyde',              'Hexanaldehyde']
# Length: 164, dtype: str

# %%
df['Duration Description'].unique()
# Out:
# <ArrowStringArray>
# [                '24 HOUR',                  '1 HOUR',
#  '8-HR RUN AVG BEGIN HOUR',           '24-HR BLK AVG',
#    '8-HR RUN AVG END HOUR',            '3-HR BLK AVG',
#                 '5 MINUTE']
# Length: 7, dtype: str

# %%
df_03 = df[(df['Parameter Name'] == 'Ozone') & (df['Duration Description'] == '1 HOUR')]
df_03.head()
# Out:
#      State Code  County Code  Site Number  Parameter Code  POC  Latitude  \
# 20            6           37         1103           44201    1  34.06659
# 64            6           37         1103           44201    1  34.06659
# 204           6           37         1103           44201    1  34.06659
# 228           6           37         1103           44201    1  34.06659
# 271           6           37         1103           44201    1  34.06659
#
#      Longitude  Datum Parameter Name Duration Description  ... AQI  \
# 20  -118.22688  WGS84          Ozone               1 HOUR  ...   .
# 64  -118.22688  WGS84          Ozone               1 HOUR  ...   .
# 204 -118.22688  WGS84          Ozone               1 HOUR  ...   .
# 228 -118.22688  WGS84          Ozone               1 HOUR  ...   .
# 271 -118.22688  WGS84          Ozone               1 HOUR  ...   .
#
#     Daily Criteria Indicator  Tribe Name  State Name  County Name  \
# ...

# %%
df_03.columns
# Out:
# Index(['State Code', 'County Code', 'Site Number', 'Parameter Code', 'POC',
#        'Latitude', 'Longitude', 'Datum', 'Parameter Name',
#        'Duration Description', 'Pollutant Standard', 'Date (Local)', 'Year',
#        'Day In Year (Local)', 'Units of Measure', 'Exceptional Data Type',
#        'Nonreg Observation Count', 'Observation Count', 'Observation Percent',
#        'Nonreg Arithmetic Mean', 'Arithmetic Mean',
#        'Nonreg First Maximum Value', 'First Maximum Value',
#        'First Maximum Hour', 'AQI', 'Daily Criteria Indicator', 'Tribe Name',
#        'State Name', 'County Name', 'City Name', 'Local Site Name', 'Address',
#        'MSA or CBSA Name', 'Data Source'],
#       dtype='str')

# %%
df_03["Date (Local)"]
# Out:
# 20       2023-01-01
# 64       2023-01-02
# 204      2023-01-03
# 228      2023-01-04
# 271      2023-01-05
#             ...
# 21122    2023-09-26
# 21168    2023-09-27
# 21218    2023-09-28
# 21261    2023-09-29
# 21305    2023-09-30
# Name: Date (Local), Length: 273, dtype: str

# %%
df_03["Date (Local)"] = pd.to_datetime(df_03["Date (Local)"])

# %%
date = df_03["Date (Local)"]
value = df_03["Arithmetic Mean"]

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.lineplot(x=date, y=value, ax=ax)
# Out:
# <Axes: xlabel='Date (Local)', ylabel='Arithmetic Mean'>

# %%
value.max()
# Out:
# np.float64(0.04575)

# %%
df_03[df_03["Arithmetic Mean"] == value.max()]["Date (Local)"]
# Out:
# 12292   2023-05-14
# Name: Date (Local), dtype: datetime64[us]

# %%
df_03[df_03["Arithmetic Mean"] > 0.035]
# Out:
#        State Code  County Code  Site Number  Parameter Code  POC  Latitude  \
# 4651            6           37         1103           44201    1  34.06659
# 4928            6           37         1103           44201    1  34.06659
# 5235            6           37         1103           44201    1  34.06659
# 7130            6           37         1103           44201    1  34.06659
# 7337            6           37         1103           44201    1  34.06659
# 7679            6           37         1103           44201    1  34.06659
# 7883            6           37         1103           44201    1  34.06659
# 8427            6           37         1103           44201    1  34.06659
# 8447            6           37         1103           44201    1  34.06659
# 9439            6           37         1103           44201    1  34.06659
# 9646            6           37         1103           44201    1  34.06659
# ...

# %%
len(df_03[df_03["Arithmetic Mean"] > 0.035])
# Out:
# 43

# %%
1. See line 23 

2a. 0.04575ppm = 45.75ppbv
2b. 43 days
